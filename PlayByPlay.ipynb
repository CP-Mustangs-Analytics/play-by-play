# %% [markdown]
# # Scraping NCAA Website POC
# To demonstrate that it can be done, I am starting by scraping one game from CP vs. Pepperdine from March 11, 2019.

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
resp = requests.get("https://www.ncaa.com/game/3333006/play-by-play")

# %%
soup = BeautifulSoup(resp.content, "html.parser")
table = soup.find_all("div")
table
# Out:
# [<div class="dialog-off-canvas-main-canvas" data-off-canvas-main-canvas="">
#  <div class="layout-container" id="ncaa-root">
#  <header class="header-main clearfix" role="header">
#  <div class="top-banner">
#  <div class="dfp" id="ad_bnr_atf_01"></div><div id="ad_oop_float_01"></div>
#  </div>
#  <div class="region region-header">
#  <div id="scoreboardWidgetWrapper">
#  </div>
# ...
